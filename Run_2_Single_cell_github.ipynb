# %%
# !conda env list
# Out:
# # conda environments:
# #
# # * -> active
# # + -> frozen
# base                     C:\Users\sanka\miniconda3
# singlecell               C:\Users\sanka\miniconda3\envs\singlecell

# %%
# !conda activate singlecell

# %%
# !pip install scanpy
# !pip install scvi-tools
# Out:
# Requirement already satisfied: scanpy in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (1.12.1)
# Requirement already satisfied: anndata>=0.10.8 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scanpy) (0.12.16)
# Requirement already satisfied: certifi in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scanpy) (2025.11.12)
# Requirement already satisfied: fast-array-utils>=1.4 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from fast-array-utils[accel,sparse]>=1.4->scanpy) (1.4.1)
# Requirement already satisfied: h5py>=3.11 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scanpy) (3.16.0)
# Requirement already satisfied: joblib in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scanpy) (1.5.3)
# Requirement already satisfied: legacy-api-wrap>=1.5 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scanpy) (1.5)
# Requirement already satisfied: matplotlib>=3.9 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scanpy) (3.10.7)
# Requirement already satisfied: natsort in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scanpy) (8.4.0)
# Requirement already satisfied: networkx>=2.8.8 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scanpy) (3.6.1)
# Requirement already satisfied: numba>=0.60 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scanpy) (0.65.1)
# Requirement already satisfied: numpy>=2 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scanpy) (2.3.5)
# Requirement already satisfied: packaging>=25 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scanpy) (25.0)
# Requirement already satisfied: pandas>=2.3 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scanpy) (2.3.3)
# Requirement already satisfied: patsy in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scanpy) (1.0.2)
# Requirement already satisfied: pynndescent>=0.5.13 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scanpy) (0.6.0)
# Requirement already satisfied: scikit-learn>=1.6 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scanpy) (1.8.0)
# Requirement already satisfied: scipy>=1.13 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scanpy) (1.17.1)
# Requirement already satisfied: seaborn>=0.13.2 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scanpy) (0.13.2)
# Requirement already satisfied: session-info2 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scanpy) (0.4.1)
# Requirement already satisfied: statsmodels>=0.14.5 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scanpy) (0.14.6)
# Requirement already satisfied: tqdm in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scanpy) (4.67.3)
# Requirement already satisfied: umap-learn>=0.5.12 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scanpy) (0.5.12)
# Requirement already satisfied: array-api-compat>=1.7.1 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from anndata>=0.10.8->scanpy) (1.14.0)
# Requirement already satisfied: scverse-misc>=0.0.3 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from anndata>=0.10.8->scanpy) (0.0.7)
# Requirement already satisfied: zarr!=3.0.*,>=2.18.7 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from anndata>=0.10.8->scanpy) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from pandas>=2.3->scanpy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from pandas>=2.3->scanpy) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from pandas>=2.3->scanpy) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from matplotlib>=3.9->scanpy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from matplotlib>=3.9->scanpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from matplotlib>=3.9->scanpy) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from matplotlib>=3.9->scanpy) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from matplotlib>=3.9->scanpy) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from matplotlib>=3.9->scanpy) (3.2.5)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from numba>=0.60->scanpy) (0.47.0)
# Requirement already satisfied: six>=1.5 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.3->scanpy) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scikit-learn>=1.6->scanpy) (3.6.0)
# Requirement already satisfied: donfig>=0.8 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.10.8->scanpy) (0.8.1.post1)
# Requirement already satisfied: google-crc32c>=1.5 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.10.8->scanpy) (1.8.0)
# Requirement already satisfied: numcodecs>=0.14 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.10.8->scanpy) (0.16.5)
# Requirement already satisfied: typing-extensions>=4.13 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.10.8->scanpy) (4.15.0)
# Requirement already satisfied: pyyaml in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from donfig>=0.8->zarr!=3.0.*,>=2.18.7->anndata>=0.10.8->scanpy) (6.0.3)
# Requirement already satisfied: colorama in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from tqdm->scanpy) (0.4.6)
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: scvi-tools in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (1.4.3)
# Requirement already satisfied: anndata in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scvi-tools) (0.12.16)
# Requirement already satisfied: docrep>=0.3.2 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scvi-tools) (0.3.2)
# Requirement already satisfied: lightning>=2.0 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scvi-tools) (2.6.5)
# Requirement already satisfied: ml-collections in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scvi-tools) (1.1.0)
# Requirement already satisfied: mudata in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scvi-tools) (0.3.8)
# Requirement already satisfied: numba>=0.60.0 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scvi-tools) (0.65.1)
# Requirement already satisfied: numpy in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scvi-tools) (2.3.5)
# Requirement already satisfied: pandas in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scvi-tools) (2.3.3)
# Requirement already satisfied: pyro-ppl in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scvi-tools) (1.9.1)
# Requirement already satisfied: rich in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scvi-tools) (15.0.0)
# Requirement already satisfied: scanpy>=1.10 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scanpy[skmisc]>=1.10->scvi-tools) (1.12.1)
# Requirement already satisfied: scikit-learn in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scvi-tools) (1.8.0)
# Requirement already satisfied: scipy in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scvi-tools) (1.17.1)
# Requirement already satisfied: sparse>=0.14.0 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scvi-tools) (0.18.0)
# Requirement already satisfied: tensorboard in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scvi-tools) (2.20.0)
# Requirement already satisfied: torch in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scvi-tools) (2.12.0)
# Requirement already satisfied: torchmetrics in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scvi-tools) (1.9.0)
# Requirement already satisfied: tqdm in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scvi-tools) (4.67.3)
# Requirement already satisfied: xarray in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scvi-tools) (2026.4.0)
# Requirement already satisfied: six in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from docrep>=0.3.2->scvi-tools) (1.17.0)
# Requirement already satisfied: PyYAML<8.0,>5.4 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from lightning>=2.0->scvi-tools) (6.0.3)
# Requirement already satisfied: fsspec<2028.0,>=2022.5.0 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0->scvi-tools) (2026.4.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from lightning>=2.0->scvi-tools) (0.15.3)
# Requirement already satisfied: packaging<27.0,>=23.0 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from lightning>=2.0->scvi-tools) (25.0)
# Requirement already satisfied: typing-extensions<6.0,>4.5.0 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from lightning>=2.0->scvi-tools) (4.15.0)
# Requirement already satisfied: pytorch-lightning in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from lightning>=2.0->scvi-tools) (2.6.5)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0->scvi-tools) (3.13.5)
# Requirement already satisfied: filelock in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from torch->scvi-tools) (3.29.0)
# Requirement already satisfied: setuptools<82 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from torch->scvi-tools) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from torch->scvi-tools) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from torch->scvi-tools) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from torch->scvi-tools) (3.1.6)
# Requirement already satisfied: colorama in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from tqdm->scvi-tools) (0.4.6)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0->scvi-tools) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0->scvi-tools) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0->scvi-tools) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0->scvi-tools) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0->scvi-tools) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0->scvi-tools) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0->scvi-tools) (1.24.2)
# Requirement already satisfied: idna>=2.0 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0->scvi-tools) (3.11)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from numba>=0.60.0->scvi-tools) (0.47.0)
# Requirement already satisfied: certifi in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (2025.11.12)
# Requirement already satisfied: fast-array-utils>=1.4 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from fast-array-utils[accel,sparse]>=1.4->scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (1.4.1)
# Requirement already satisfied: h5py>=3.11 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (3.16.0)
# Requirement already satisfied: joblib in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (1.5.3)
# Requirement already satisfied: legacy-api-wrap>=1.5 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (1.5)
# Requirement already satisfied: matplotlib>=3.9 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (3.10.7)
# Requirement already satisfied: natsort in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (8.4.0)
# Requirement already satisfied: patsy in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (1.0.2)
# Requirement already satisfied: pynndescent>=0.5.13 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (0.6.0)
# Requirement already satisfied: seaborn>=0.13.2 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (0.13.2)
# Requirement already satisfied: session-info2 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (0.4.1)
# Requirement already satisfied: statsmodels>=0.14.5 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (0.14.6)
# Requirement already satisfied: umap-learn>=0.5.12 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (0.5.12)
# Requirement already satisfied: array-api-compat>=1.7.1 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from anndata->scvi-tools) (1.14.0)
# Requirement already satisfied: scverse-misc>=0.0.3 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from anndata->scvi-tools) (0.0.7)
# Requirement already satisfied: zarr!=3.0.*,>=2.18.7 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from anndata->scvi-tools) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from pandas->scvi-tools) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from pandas->scvi-tools) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from pandas->scvi-tools) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from matplotlib>=3.9->scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from matplotlib>=3.9->scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from matplotlib>=3.9->scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from matplotlib>=3.9->scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from matplotlib>=3.9->scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from matplotlib>=3.9->scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools) (3.2.5)
# Requirement already satisfied: scikit-misc>=0.5.1 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scanpy[skmisc]>=1.10->scvi-tools) (0.5.2)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scikit-learn->scvi-tools) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from sympy>=1.13.3->torch->scvi-tools) (1.3.0)
# Requirement already satisfied: donfig>=0.8 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from zarr!=3.0.*,>=2.18.7->anndata->scvi-tools) (0.8.1.post1)
# Requirement already satisfied: google-crc32c>=1.5 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from zarr!=3.0.*,>=2.18.7->anndata->scvi-tools) (1.8.0)
# Requirement already satisfied: numcodecs>=0.14 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from zarr!=3.0.*,>=2.18.7->anndata->scvi-tools) (0.16.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from jinja2->torch->scvi-tools) (3.0.3)
# Requirement already satisfied: absl-py in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from ml-collections->scvi-tools) (2.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from pyro-ppl->scvi-tools) (3.4.0)
# Requirement already satisfied: pyro-api>=0.1.1 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from pyro-ppl->scvi-tools) (0.1.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from rich->scvi-tools) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from rich->scvi-tools) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from markdown-it-py>=2.2.0->rich->scvi-tools) (0.1.2)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from tensorboard->scvi-tools) (1.80.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from tensorboard->scvi-tools) (3.10.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from tensorboard->scvi-tools) (7.35.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from tensorboard->scvi-tools) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from tensorboard->scvi-tools) (3.1.8)
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import scanpy as sc
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import scvi as scvi
from IPython.display import display
# Out:
# W0613 17:23:12.679000 8164 site-packages\torch\utils\flop_counter.py:29] triton not found; flop counting will not work for triton kernels

# %%
sc.settings.verbosity = 1

# %%
os.getcwd()
# Out:
# 'C:\\Users\\sanka\\Desktop\\SingleCell_github'

# %%
results_file = 'results/pbmc3k.h5ad'

# %% [markdown]
# # Load data

# %% [raw]
# Tool        Format
# Scanpy	    .h5ad , .mtx
# Seurat	    .Rds
# Cellxgene   .h5ad
# Monocle	    .cds

# %%
# Read matrix [Counts, Barcodes(cells), and Features(Genes)]
adata = sc.read_10x_mtx(r"C:\Users\sanka\Desktop\SingleCell_github\data\pbmc3k_filtered_gene_bc_matrices\filtered_gene_bc_matrices\hg19")

# %%
# # Make the var(gene) name unique 
adata.var_names_make_unique()

# %%
#  Checking whether the names are unique now or not 
adata.var_names.is_unique
# Out:
# True

# %% [markdown]
# # EDA

# %%
def EDA(adata):

    print(f"Number of Cells : {len(adata.obs)}")
    print(f"Number of Genes : {len(adata.var)}")

    Total_elements = len(adata.obs)*len(adata.var) 
    Nonzero_elements = adata.X.nnz
    print(f"Sparsity of the data : {((Total_elements-Nonzero_elements)/Total_elements)*100:.2f} % \n")

    # Identification of Mitochondrial, Ribosomal and Hemoglobin Genes
    adata.var["Mitochondrial"] = adata.var_names.str.startswith("MT-")  # MORE MT = DYING CELL BUT DEPENDS UPON THE CELL TYPE 
    adata.var["Ribosomal"] = adata.var_names.str.startswith(("RPS","RPL")) 
    adata.var["Hemo"] = adata.var_names.str.startswith("^HB[^(P)]")

    print(f"Number of Mitochondrial Genes : {(adata.var["Mitochondrial"]).sum()}")
    print(f"Number of Ribosomal Genes : {(adata.var["Ribosomal"]).sum()}")
    print(f"Number of Hemoglobin Genes : {(adata.var["Hemo"]).sum()}\n")

    # PLotting the top 20 highly expressed genes
    print("Top 20 Genes Expressed")
    sc.pl.highest_expr_genes(adata, n_top=20)

    # Calculating per cell level qc metrices
    sc.pp.calculate_qc_metrics(adata,percent_top=None,log1p=False,qc_vars =['Mitochondrial','Ribosomal','Hemo'] ,inplace=True )
    print("\n")  
    
    # CELL LEVEL QC METRICES
    print("CELL LEVEL QC METRICES SUMMARY \n")
    cell_qc = adata.obs[['n_genes_by_counts','total_counts','pct_counts_Mitochondrial','pct_counts_Ribosomal']].describe()
    display(cell_qc)
    print(f"Minimum Number of Genes in a cell : {min(adata.obs['n_genes_by_counts'])}")
    print(f"Maximum Number of Genes in a cell : {max(adata.obs['n_genes_by_counts'])}")
    print(f"Number of cell with less than 300 genes expressed : {(adata.obs['n_genes_by_counts'] < 300 ).sum()}")
    print(f"Mitochondrial Percentage Range : {min(adata.obs['pct_counts_Mitochondrial']):.0f} % - {max(adata.obs['pct_counts_Mitochondrial']):.0f} %  ")
    print(f"Ribosomal Percentage Range : {min(adata.obs['pct_counts_Ribosomal']):.0f} % - {max(adata.obs['pct_counts_Ribosomal']):.0f} %  ")
    print("\n\n")  

    # GENE LEVEL METRICES 
    print("GENE LEVEL QC METRICES SUMMARY \n")
    gene_qc = adata.var[['n_cells_by_counts','total_counts']].describe()
    display(gene_qc)
    print(f"Minimum number of cells in which a gene is expressed : {min(adata.var["n_cells_by_counts"])}")
    print(f"Maximum number of cells in which a gene is expressed : {max(adata.var["n_cells_by_counts"])}")
    print(f"Number of Genes which are expressed in less than 3 cells : {(adata.var["n_cells_by_counts"] < 3).sum()}")

    summary_stats = {
    "n_cells": len(adata.obs),
    "n_genes": len(adata.var),
    "sparsity": ((Total_elements-Nonzero_elements)/Total_elements)*100,
    "n_mt_genes": adata.var["Mitochondrial"].sum(),
    "n_ribo_genes": adata.var["Ribosomal"].sum(),
    "n_hemo_genes": adata.var["Hemo"].sum(),
    "cells_lt_300_genes": (adata.obs['n_genes_by_counts'] < 300).sum(),
    "genes_lt_3_cells": (adata.var["n_cells_by_counts"] < 3).sum()
    }

    return summary_stats, cell_qc, gene_qc

summary_stats , cell_qc , gene_qc = EDA(adata)
# Out:
# Number of Cells : 2700
# Number of Genes : 32738
# Sparsity of the data : 97.41 %
#
# Number of Mitochondrial Genes : 13
# Number of Ribosomal Genes : 106
# Number of Hemoglobin Genes : 0
#
# Top 20 Genes Expressed
# CELL LEVEL QC METRICES SUMMARY
#        n_genes_by_counts  total_counts  pct_counts_Mitochondrial  \
# count        2700.000000   2700.000000               2700.000000
# mean          846.994074   2366.900391                  2.215132
# std           282.104964   1094.262085                  1.165438
# min           212.000000    548.000000                  0.000000
# 25%           690.000000   1757.750000                  1.536238
# 50%           817.000000   2197.000000                  2.029639
# 75%           953.250000   2763.000000                  2.640218
# max          3422.000000  15844.000000                 22.569027
#
#        pct_counts_Ribosomal
# count           2700.000000
# mean              34.949211
# std               10.215296
# min                1.055966
# 25%               26.332963
# 50%               36.769516
# 75%               43.353328
# max               59.441711
# Minimum Number of Genes in a cell : 212
# Maximum Number of Genes in a cell : 3422
# Number of cell with less than 300 genes expressed : 15
# Mitochondrial Percentage Range : 0 % - 23 %
# Ribosomal Percentage Range : 1 % - 59 %
#
#
#
# GENE LEVEL QC METRICES SUMMARY
#        n_cells_by_counts   total_counts
# count       32738.000000   32738.000000
# mean           69.854114     195.205292
# std           238.263898    2301.482666
# min             0.000000       0.000000
# 25%             0.000000       0.000000
# 50%             1.000000       1.000000
# 75%            35.000000      37.000000
# max          2700.000000  161685.000000
# Minimum number of cells in which a gene is expressed : 0
# Maximum number of cells in which a gene is expressed : 2700
# Number of Genes which are expressed in less than 3 cells : 19024

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 2700 × 32738
#     obs: 'n_genes_by_counts', 'total_counts', 'total_counts_Mitochondrial', 'pct_counts_Mitochondrial', 'total_counts_Ribosomal', 'pct_counts_Ribosomal', 'total_counts_Hemo', 'pct_counts_Hemo'
#     var: 'gene_ids', 'Mitochondrial', 'Ribosomal', 'Hemo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'

# %% [markdown]
# #### Visualizing QC Metrices

# %%
# Plotting QC Metrices 

def Plotting(adata): 

    # Figure path 
    figure_path = 'Figures/'
    
    # Setting the figure and axes objects for a 3x1 grid
    fig, axes = plt.subplots(nrows=1, ncols=6 , figsize=(45, 8))

    # FIGURE 1A : GENES DISTRIBUTION
    fig_1 = axes[0]
    fig_1.hist(adata.obs['n_genes_by_counts'], bins = 50, alpha= 0.7 , color='steelblue',edgecolor='black')
    fig_1.set_xlabel("Genes per cell")
    fig_1.set_ylabel("Number of cells")
    fig_1.set_title("Gene Distribution")
    fig_1.axvline(np.median(adata.obs['n_genes_by_counts']), color = 'red', linestyle = '--', label = f"Median {np.median(adata.obs['n_genes_by_counts']):.0f}")
    fig_1.legend()

    # FIGURE 1B : GENE DISTRIBUTION VIOLIN PLOT  
    ax1_viol = axes[1]
    sc.pl.violin(adata, "n_genes_by_counts", jitter=0.4, ax=ax1_viol, show=False )
    ax1_viol.set_title("Genes per cell (Violin Plot)")
    ax1_viol.set_xlabel("") # Clear redundant x-label

    # FIGURE 2A : UMI DISTRIBUTION
    fig_2 = axes[2]
    fig_2.hist(adata.obs['total_counts'], bins = 50, alpha= 0.7 , color='yellow',edgecolor='black')
    fig_2.set_xlabel("UMI per cell")
    fig_2.set_ylabel("Number of cells")
    fig_2.set_title("UMI Distribution")
    fig_2.axvline(np.median(adata.obs['total_counts']), color = 'red', linestyle = '--', label = f"Median {np.median(adata.obs['total_counts']):.0f}")
    fig_2.legend()

    # FIGURE 2B : UMI DISTRIBUTION Violin Plot
    ax2_viol = axes[3]
    sc.pl.violin(adata, "total_counts", jitter=0.4, ax=ax2_viol, show=False)
    ax2_viol.set_title("UMI Counts per cell (Violin Plot)")
    ax2_viol.set_xlabel("")
    
    # FIGURE 3A : MITOCHONDRIAL DISTRIBUITON
    fig_3 = axes[4]
    fig_3.hist(adata.obs['pct_counts_Mitochondrial'], bins = 50, alpha= 0.7 , color='green',edgecolor='black')
    fig_3.set_xlabel("Mitochondrial % per cell")
    fig_3.set_ylabel("Number of cells")
    fig_3.set_title("Mitochondiral Distribution")
    fig_3.axvline(np.median(adata.obs['pct_counts_Mitochondrial']), color = 'red', linestyle = '--', label = f"Median {np.median(adata.obs['pct_counts_Mitochondrial']):.2f} %")
    fig_3.legend()

    # FIGURE 3B : MITOCHONDRIAL DITRIBUTION VIOLIN PLOT
    ax3_viol = axes[5]
    sc.pl.violin(adata, "pct_counts_Mitochondrial", jitter=0.4, ax=ax3_viol, show=False)
    ax3_viol.set_title("Mitochondrial % (Violin Plot)")
    ax3_viol.set_xlabel("")

    plt.savefig(f"{figure_path}/01_qc_plots.png" ,bbox_inches="tight")
    plt.close()

Plotting(adata)

# %% [markdown]
# ## Preprocessing | Quality Control

# %% [markdown]
# ### Basic filtering based on Graphs

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 2700 × 32738
#     obs: 'n_genes_by_counts', 'total_counts', 'total_counts_Mitochondrial', 'pct_counts_Mitochondrial', 'total_counts_Ribosomal', 'pct_counts_Ribosomal', 'total_counts_Hemo', 'pct_counts_Hemo'
#     var: 'gene_ids', 'Mitochondrial', 'Ribosomal', 'Hemo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'

# %%
adata_qc = adata.copy()

# %%
# Cell filtering 
sc.pp.filter_cells(adata_qc,min_genes = 200)
sc.pp.filter_cells(adata_qc,max_genes = 2500)

# Gene filtering 
sc.pp.filter_genes(adata_qc,min_cells = 3 )  # ~58 % of genes are not expressed in 3 cells | 32738 - 19024 = 13714

# %%
adata_qc
# Out:
# AnnData object with n_obs × n_vars = 2695 × 13673
#     obs: 'n_genes_by_counts', 'total_counts', 'total_counts_Mitochondrial', 'pct_counts_Mitochondrial', 'total_counts_Ribosomal', 'pct_counts_Ribosomal', 'total_counts_Hemo', 'pct_counts_Hemo', 'n_genes'
#     var: 'gene_ids', 'Mitochondrial', 'Ribosomal', 'Hemo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'n_cells'

# %%
# Removing Mitochondrial and Ribosomal Genes  
adata_qc = adata_qc[adata_qc.obs['pct_counts_Mitochondrial'] < 5 , : ]
adata_qc = adata_qc[adata_qc.obs['pct_counts_Ribosomal'] > 5 , : ]

# %%
print(f"Cells Before filtering : {len(adata.obs)}")
print(f"Genes Before filtering : {len(adata.var)}\n ")

print(f"Cells after filtering : {len(adata_qc.obs)}")
print(f"Genes after filtering : {len(adata_qc.var)}")
# Out:
# Cells Before filtering : 2700
# Genes Before filtering : 32738
#
# Cells after filtering : 2628
# Genes after filtering : 13673

# %%
adata_qc.obs_names.is_unique
# Out:
# True

# %% [markdown]
# ## Doublet Detection - SCRUBLET

# %%
# !pip install scikit-image
# Out:
# Requirement already satisfied: scikit-image in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (0.26.0)
# Requirement already satisfied: numpy>=1.24 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scikit-image) (2.3.5)
# Requirement already satisfied: scipy>=1.11.4 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scikit-image) (1.17.1)
# Requirement already satisfied: networkx>=3.0 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scikit-image) (3.6.1)
# Requirement already satisfied: pillow>=10.1 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scikit-image) (12.0.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scikit-image) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scikit-image) (2026.2.24)
# Requirement already satisfied: packaging>=21 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scikit-image) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from scikit-image) (0.4)
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
sc.pp.scrublet(adata_qc)
# Out:
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scanpy\preprocessing\_scrublet\__init__.py:297: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   adata.obs["doublet_score"] = scrubbed["obs"]["doublet_score"]

# %%
# Checking how many Cells are marked as doublets using scrublet
scrublet_doublets = (adata_qc.obs['predicted_doublet'].groupby(adata_qc.obs['predicted_doublet'])).count()
plt.bar(scrublet_doublets.index.astype(str),
        scrublet_doublets.values,
        color='blue',
        edgecolor='black')

plt.xlabel('Predicted Doublet')
plt.ylabel('Number of Cells')
plt.title('Scrublet Doublet Classification')
plt.savefig('Figures/02_doublet_detection_scrublet.png')
plt.show()

print(scrublet_doublets)
# Out:
# predicted_doublet
# False    2596
# True       32
# Name: predicted_doublet, dtype: int64

# %% [markdown]
# # Normalisation

# %%
adata_qc.layers['counts'] = adata_qc.X.copy()
# Out:
# C:\Users\sanka\AppData\Local\Temp\ipykernel_8164\1416119010.py:1: ImplicitModificationWarning: Setting element `.layers['counts']` of view, initializing view as actual.
#   adata_qc.layers['counts'] = adata_qc.X.copy()

# %%
sc.pp.normalize_total(adata_qc , target_sum = 1e4 )

# %%
sc.pp.log1p(adata_qc)

# %% [markdown]
# # HVG

# %%
sc.pp.highly_variable_genes(
    adata_qc,
    flavor="seurat_v3",
    n_top_genes=2000,
    layer="counts"
)

# %%
sc.pl.highly_variable_genes(adata_qc, save='highly_variable_genes.png')
# Out:
# WARNING: saving figure to file figures\filter_genes_dispersionhighly_variable_genes.png
# C:\Users\sanka\AppData\Local\Temp\ipykernel_8164\3302737342.py:1: FutureWarning: Argument `save` is deprecated and will be removed in a future version. Use `sc.pl.plot(show=False).figure.savefig()` instead.
#   sc.pl.highly_variable_genes(adata_qc, save='highly_variable_genes.png')

# %%
adata_qc = adata_qc[:, adata_qc.var.highly_variable]

# %%
adata_qc = adata_qc.copy()

# %%
adata_qc.is_view
# Out:
# False

# %% [markdown]
# ## Doublet Detection - SCVI TOOLS

# %%
import scvi

# %%
import torch

print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.get_device_name(0))
# Out:
# True
# 1
# NVIDIA GeForce RTX 3050 Laptop GPU

# %%
scvi.model.SCVI.setup_anndata(adata_qc, layers = 'counts')
vae = scvi.model.SCVI(adata_qc)
vae.train(accelerator = 'gpu' , devices = 1)
# Out:
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\data\fields\_base_field.py:63: UserWarning: adata.X does not contain unnormalized count data. Are you sure this is what you want?
#   self.validate_field(adata)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# You are using a CUDA device ('NVIDIA GeForce RTX 3050 Laptop GPU') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\lightning\pytorch\utilities\_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Training:   0%|          | 0/400 [00:00<?, ?it/s]
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
# ...
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\module\_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# `Trainer.fit` stopped: `max_epochs=400` reached.

# %%
solo = scvi.external.SOLO.from_scvi_model(vae)
solo.train(accelerator = 'gpu' , devices = 1)
# Out:
# INFO     Creating doublets, preparing SOLO model.
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scvi\data\fields\_base_field.py:63: UserWarning: adata.X does not contain unnormalized count data. Are you sure this is what you want?
#   self.validate_field(adata)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\lightning\pytorch\utilities\_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Training:   0%|          | 0/400 [00:00<?, ?it/s]
# Monitored metric validation_loss did not improve in the last 30 records. Best score: 0.009. Signaling Trainer to stop.

# %%
solo_doublets = solo.predict()
solo_doublets['Prediction'] = solo.predict(soft=False)

solo_doublets.groupby('Prediction').count()
# Out:
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\torch\utils\_contextlib.py:124: UserWarning: Prior to scvi-tools 1.1.3, `SOLO.predict` with `soft=True` (the default option) returned logits instead of probabilities. This behavior has since been corrected to return probabilities. The previous behavior can be replicated by passing in `return_logits=True`.
#   return func(*args, **kwargs)
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\torch\utils\_contextlib.py:124: UserWarning: Prior to scvi-tools 1.1.3, `SOLO.predict` with `soft=True` (the default option) returned logits instead of probabilities. This behavior has since been corrected to return probabilities. The previous behavior can be replicated by passing in `return_logits=True`.
#   return func(*args, **kwargs)
#             doublet  singlet
# Prediction
# doublet           6        6
# singlet        2616     2616

# %%
adata_qc.obs['Solo_prediction'] = solo_doublets['Prediction']

# %%
adata_qc
# Out:
# AnnData object with n_obs × n_vars = 2622 × 2000
#     obs: 'n_genes_by_counts', 'total_counts', 'total_counts_Mitochondrial', 'pct_counts_Mitochondrial', 'total_counts_Ribosomal', 'pct_counts_Ribosomal', 'total_counts_Hemo', 'pct_counts_Hemo', 'n_genes', 'doublet_score', 'predicted_doublet', '_scvi_batch', '_scvi_labels', 'Solo_prediction'
#     var: 'gene_ids', 'Mitochondrial', 'Ribosomal', 'Hemo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'n_cells', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm'
#     uns: 'scrublet', 'log1p', 'hvg', '_scvi_uuid', '_scvi_manager_uuid'
#     layers: 'counts'

# %% [markdown]
# # Doublet Removal

# %%
adata_qc = adata_qc[~adata_qc.obs.predicted_doublet]

# %%
adata_qc
# Out:
# View of AnnData object with n_obs × n_vars = 2596 × 2000
#     obs: 'n_genes_by_counts', 'total_counts', 'total_counts_Mitochondrial', 'pct_counts_Mitochondrial', 'total_counts_Ribosomal', 'pct_counts_Ribosomal', 'total_counts_Hemo', 'pct_counts_Hemo', 'n_genes', 'doublet_score', 'predicted_doublet'
#     var: 'gene_ids', 'Mitochondrial', 'Ribosomal', 'Hemo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'n_cells', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm'
#     uns: 'scrublet', 'log1p', 'hvg'
#     layers: 'counts'

# %%
# Regression removes unwanted technical effects
sc.pp.regress_out(adata_qc, ['total_counts','pct_counts_Mitochondrial','pct_counts_Ribosomal'])

# %%
# Scaling sets every gene on a same variance scale 
sc.pp.scale(adata_qc, max_value = 10)

# %% [markdown]
# # Dimensionality Reduction

# %%
# Calculating PCs 
sc.tl.pca(adata_qc)

# BY DEFAULT IT CALCULATES 50 PCs
# Results stored in adata_qc.obsm["X_pca"]

# %%
sc.pl.pca_variance_ratio(adata_qc, n_pcs = 50 , log = True , save = '03_dimensional_reduction.png')
# Out:
# WARNING: saving figure to file figures\pca_variance_ratio03_dimensional_reduction.png
# C:\Users\sanka\AppData\Local\Temp\ipykernel_8164\4285427793.py:1: FutureWarning: Argument `save` is deprecated and will be removed in a future version. Use `sc.pl.plot(show=False).figure.savefig()` instead.
#   sc.pl.pca_variance_ratio(adata_qc, n_pcs = 50 , log = True , save = '03_dimensional_reduction.png')

# %% [raw]
# Usually the first ~10–30 PCs explain most of the variance
# X-axis: Principal Component number (PC1, PC2, etc)
# Y-axis: Fraction of total variance.

# %% [raw]
# # SOME ISSUES :
#
# 1. Didn't removed Mitochondrial and Ribosmal Genes.
# 2. Didn't make the HVG Graph right ( Ideally we should just calculate and not subset simultaneusly , Just calculate -> Plot -> Filter out )
#  SOLVED - 11/06/2026
#
# Note : Re running scrublet or Solo after removal of doublets once will result in new set of doublets because the algorithms depends upon relative neighbours )

# %%
# Checking which genes contributes to pca1 and pca2 
sc.pl.pca_loadings(adata_qc, components=(1, 2), include_lowest=True,save = '05_PC1_PC2_contributions.png' )
# Out:
# WARNING: saving figure to file figures\pca_loadings05_PC1_PC2_contributions.png
# C:\Users\sanka\AppData\Local\Temp\ipykernel_8164\1289364845.py:2: FutureWarning: Argument `save` is deprecated and will be removed in a future version. Use `sc.pl.plot(show=False).figure.savefig()` instead.
#   sc.pl.pca_loadings(adata_qc, components=(1, 2), include_lowest=True,save = '05_PC1_PC2_contributions.png' )

# %%
adata_qc
# Out:
# AnnData object with n_obs × n_vars = 2628 × 2000
#     obs: 'n_genes_by_counts', 'total_counts', 'total_counts_Mitochondrial', 'pct_counts_Mitochondrial', 'total_counts_Ribosomal', 'pct_counts_Ribosomal', 'total_counts_Hemo', 'pct_counts_Hemo', 'n_genes'
#     var: 'gene_ids', 'Mitochondrial', 'Ribosomal', 'Hemo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'n_cells', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'mean', 'std'
#     uns: 'log1p', 'hvg', 'pca'
#     obsm: 'X_pca'
#     varm: 'PCs'
#     layers: 'counts'

# %% [markdown]
# # Computing the neighborhood graph

# %%
sc.pp.neighbors(adata_qc, n_neighbors=10, n_pcs=40)

# %% [raw]
# This Calculates each cell's nearest 10 neighbours and uses only first 40 PCs saved in:
# adata.obsp['connectivities']
# adata.obsp['distances']

# %% [markdown]
# # Embedding the Neighbourhood Graph

# %%
sc.tl.umap(adata_qc)
sc.pl.umap(adata_qc)

# %%
# Doublets checking using UMAP 
sc.pl.umap(adata_qc , color = ["doublet_score",'predicted_doublet'])

# %% [markdown]
# # Clustering

# %%
# !pip install leidenalg
# Out:
# Requirement already satisfied: leidenalg in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (0.11.0)
# Requirement already satisfied: igraph<2.0,>=1.0.0 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from leidenalg) (1.0.0)
# Requirement already satisfied: texttable>=1.6.2 in c:\users\sanka\appdata\local\programs\python\python314\lib\site-packages (from igraph<2.0,>=1.0.0->leidenalg) (1.7.0)
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Clustering Using the Leiden Algorithm 
sc.tl.leiden(adata_qc, resolution = 0.7,flavor = "igraph" , n_iterations = 2 )

# %%
sc.pl.umap(adata_qc , color = "leiden", show = False)
plt.savefig('Figures/04_Leiden_clustering.png')
plt.show()

# Alternative code : sc.pl.umap(adata_qc , color = "leiden", save = 'Figures/04_Leiden_clustering.png')

# %%
adata_qc.var.loc["PPBP", ["highly_variable"]]
# Out:
# highly_variable    True
# Name: PPBP, dtype: object

# %% [markdown]
# # Cell Type annotation

# %% [raw]
# Now that we have clusters,  we need to know which broad category each cluster belongs to , Mainly checking for ,"CST3","NKG7","PPBP".
#
# NKG7 → NK cells
# PPBP → Megakaryocytes
# CST3 → Myeloid cells

# %%
sc.pl.umap(adata_qc , color = ["leiden","CST3","NKG7","PPBP"])

# %%
sc.pl.umap(adata_qc , color = ["leiden","CST3","NKG7","PPBP"])

# %%
# Differential expression analsyis cluster wise
sc.tl.rank_genes_groups(adata_qc, "leiden", mask_var="highly_variable", method='wilcoxon')
sc.pl.rank_genes_groups(adata_qc, n_genes=25, sharey=False)
# Out:
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:484: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:484: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:484: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:484: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:484: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:484: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:484: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:484: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(

# %%
# Differential expression analsyis cluster wise
sc.tl.rank_genes_groups(adata_qc, "leiden", mask_var="highly_variable", method='wilcoxon')
sc.pl.rank_genes_groups(adata_qc, n_genes=25, sharey=False)
# Out:
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:484: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:484: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:484: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:484: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:484: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:484: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:484: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# C:\Users\sanka\AppData\Local\Programs\Python\Python314\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:484: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(

# %%
# Top 10 Expressed genes in clusters
pd.DataFrame(adata_qc.uns['rank_genes_groups']['names']).head(30)
# Out:
#                0         1              2              3                    4  \
# 0           CCL5      CD74            LTB            LYZ                 NKG7
# 1           NKG7   HLA-DRA           IL32         S100A9                 GNLY
# 2           IL32  HLA-DRB1            B2M         S100A8                 GZMB
# 3            B2M  HLA-DPB1            CD2           CST3                 CTSW
# 4           GZMA  HLA-DPA1         TMSB4X            FTL                 PRF1
# 5           CST7  HLA-DQA1         MALAT1           FCN1                HKDC1
# 6           CTSW     CD79A           IL7R         TYROBP        RP13-131K19.7
# 7         MALAT1  HLA-DQB1         GIMAP7         LGALS2               SEMA4F
# 8           GZMK     CD79B       TRAF3IP3           FTH1           AC073072.5
# 9         VPS13A      CD37           AQP3           AIF1               ZBTB32
# 10         CENPF  HLA-DRB5          KLRC2         SEMA4F                PVRL3
# 11          GZMH     MS4A1           CD27     AC195454.1         RP3-395M20.9
# 12           CD2  HLA-DQA2         CDKN2A          HKDC1               PMEPA1
# 13         DHX36   HLA-DMA  CTC-444N24.11           GPX1        RP11-247A12.2
# 14        PACRGL   HLA-DMB   RP11-393I2.4   RP3-395M20.9           AC195454.1
# 15          PCNX      PLD4         CAPN12         LGALS1              BCDIN3D
# 16         TRIT1  KIAA0101         ZNF397          PLEK2               TRIM23
# 17  RP3-325F22.5     TROAP          RAB12      RBM26-AS1        RP11-421L21.3
# 18        RHBDD3     GATA2  RP11-324I22.4          YPEL4                 SCAI
# 19          WBP5      ARG2  CTD-2302E22.4           RGMB              C8orf44
# 20           C1R     KIFC1          HEMK1           URB2                SGSM2
# 21          ADAL     CCNA2            FYB           ORC2  XXbac-BPGBPG55C20.2
# 22       C1orf51      CDT1          OBSCN            NOG               ZNF747
# 23          LYAR    ZNF503  RP11-511B23.1           LST1                 ORC2
# 24        SPATA7     TMCC2         NCKAP1        C8orf44             C16orf58
# 25         FOPNL     PTCRA          ACAP1           TYMP                 CST7
# 26         NPHP3      PTX3  RP11-493L12.4          Y_RNA                 MZB1
# 27         DPY30     TCL1A         ZNF350   RP11-219B4.7                PDE6B
# 28        RUNDC1     KCNC3       TGFBRAP1   RP5-887A10.1        RP11-706O15.1
# 29        CYB561      C1QC           PAK3  RP13-131K19.7           AC113189.5
#
#                 5              6              7
# 0   RP11-879F14.2     AC009501.4  RP11-511B23.1
# 1           C5AR2   RP11-219B4.7         NCKAP1
# 2          GPRC5C            IL6           PAK3
# 3          LY6G6F          MTRF1          USP30
# 4           ITGB3           PLD6          OBSCN
# 5            AGO4         ZNF528  RP11-493L12.4
# 6         CEACAM4           PAK3         DRAXIN
# 7           FAM3D       C1orf186  RP11-164H13.1
# 8            QPRT          PLEK2          KCNG1
# 9           GBGT1          BACE2          PDZD4
# 10        MTERFD1           PURA  RP11-324I22.4
# 11         FCGR3B        CAMK2N1           GNG3
# 12           EDC3         FBXO33   CTB-152G17.6
# 13         IL1RAP          Y_RNA          BACE2
# 14        SLC6A12         PGM2L1  CTA-250D10.23
# 15   CTC-378H22.1  RP11-111M22.3   RP11-428G5.5
# 16         RAB27B          SIRT1         PGM2L1
# 17        RANBP17  RP11-400F19.6            IL6
# 18          SPARC           FHL1         ICOSLG
# 19       SIGLEC12         ANKEF1           NEK8
# 20           CD93  RP11-493L12.4          STAU2
# 21           TPM2     PAXIP1-AS1         ZNF175
# 22  RP11-701P16.5          TCL1B       ARHGAP24
# 23          JAZF1      RBM26-AS1           SUOX
# 24         DUSP10         FCGR3A        CAMK2N1
# 25         RNF165          PPIL4     AC009501.4
# 26           ACY3         NCKAP1   RP11-430B1.2
# 27          FRAT1           MDS2          EXOC6
# 28       SERPING1           RGMB          RAB12
# 29         KCTD10         PDIK1L         ERV3-1

# %%
# Top 10 Expressed genes in clusters
pd.DataFrame(adata_qc.uns['rank_genes_groups']['names']).head(10)
# Out:
#         0       1              2         3       4              5  \
# 0    CCL5    IL32  RP11-879F14.2      CD74     LYZ           GZMB
# 1    NKG7     LTB         GPRC5C   HLA-DRA  S100A9           NKG7
# 2     B2M     B2M          C5AR2  HLA-DRB1  S100A8           GNLY
# 3    GZMA    IL7R        CEACAM4  HLA-DPB1    CST3           CTSW
# 4    CST7  GIMAP7         LY6G6F  HLA-DPA1     FTL           PRF1
# 5    IL32  TMSB4X           AGO4  HLA-DQA1    FCN1          HKDC1
# 6    CTSW     CD2          ITGB3     CD79A  TYROBP  RP13-131K19.7
# 7  MALAT1     VIM          GBGT1  HLA-DQB1  LGALS2         SEMA4F
# 8    GZMK  S100A4          FAM3D     CD79B    FTH1         ZBTB32
# 9    GZMH   ANXA1           QPRT      CD37    AIF1           URB2
#
#                6              7
# 0     AC009501.4  RP11-511B23.1
# 1   RP11-219B4.7         NCKAP1
# 2     AC195454.1           PAK3
# 3           PLD6          USP30
# 4         FCGR3A          OBSCN
# 5          MTRF1  CTA-250D10.23
# 6           PAK3         DRAXIN
# 7            IL6  RP11-164H13.1
# 8          BACE2          KCNG1
# 9  RP11-111M22.3          PDZD4

# %%
marker_genes = [
    *["IL7R", "CD79A", "MS4A1", "LYZ", "CD14"],
    *["LGALS3", "S100A8", "GNLY", "NKG7", "KLRB1"],
    *["FCGR3A", "MS4A7", "FCER1A", "CST3", "PPBP"],
]

sc.pl.dotplot(
    adata_qc,
    marker_genes,
    groupby="leiden"
)

# %%
sc.pl.dotplot(
    adata_qc,
    [
        "FCER1A","CST3","CD74","HLA-DRA",
        "PPBP","PF4","SDPR",
        "FCGR3A","MS4A7",
        "CD8A","CD8B"
    ],
    groupby="leiden"
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 sc.pl.dotplot(
#       2     adata_qc,
#       3     [
#       4         "FCER1A","CST3","CD74","HLA-DRA",
#       5         "PPBP","PF4","SDPR",
#       6         "FCGR3A","MS4A7",
#       7         "CD8A","CD8B"
#       8     ],
#       9     groupby="leiden"
#      10 )
#
#     [... skipping hidden 1 frame]
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\scanpy\plotting\_dotplot.py:1174, in dotplot(adata, var_names, groupby, use_raw, log, num_categories, categories_order, expression_cutoff, mean_only_expressed, standard_scale, title, colorbar_title, size_title, figsize, dendrogram, gene_symbols, var_group_positions, var_group_labels, var_group_rotation, layer, swap_axes, dot_color_df, show, save, ax, return_fig, vmin, vmax, vcenter, norm, cmap, group_colors, dot_max, dot_min, smallest_dot, **kwds)
#    1167 if group_colors is not None and cmap != DotPlot.DEFAULT_COLORMAP:
#    1168     warn(
#    1169         "Both `cmap` and `group_colors` are specified. "
#    1170         "`group_colors` takes precedence for the specified groups.",
#    1171         UserWarning,
#    1172     )
# -> 1174 dp = DotPlot(
#    1175     adata,
#    1176     var_names,
#    1177     groupby,
#    1178     use_raw=use_raw,
#    1179     log=log,
#    1180     num_categories=num_categories,
#    1181     categories_order=categories_order,
#    1182     expression_cutoff=expression_cutoff,
#    1183     mean_only_expressed=mean_only_expressed,
#    1184     standard_scale=standard_scale,
#    1185     title=title,
#    1186     figsize=figsize,
#    1187     gene_symbols=gene_symbols,
#    1188     var_group_positions=var_group_positions,
#    1189     var_group_labels=var_group_labels,
#    1190     var_group_rotation=var_group_rotation,
#    1191     layer=layer,
#    1192     dot_color_df=dot_color_df,
#    1193     group_colors=group_colors,
#    1194     ax=ax,
#    1195     vmin=vmin,
#    1196     vmax=vmax,
#    1197     vcenter=vcenter,
#    1198     norm=norm,
#    1199     **kwds,
#    1200 )
#    1202 if dendrogram:
#    1203     dp.add_dendrogram(dendrogram_key=_dk(dendrogram))
#
#     [... skipping hidden 1 frame]
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\scanpy\plotting\_dotplot.py:169, in DotPlot.__init__(self, adata, var_names, groupby, use_raw, log, num_categories, categories_order, title, figsize, gene_symbols, var_group_positions, var_group_labels, var_group_rotation, layer, expression_cutoff, mean_only_expressed, standard_scale, dot_color_df, dot_size_df, ax, vmin, vmax, vcenter, norm, group_colors, **kwds)
#     116 @old_positionals(
#     117     "use_raw",
#     118     "log",
#    (...)    167     **kwds,
#     168 ) -> None:
# --> 169     BasePlot.__init__(
#     170         self,
#     171         adata,
#     172         var_names,
#     173         groupby,
#     174         use_raw=use_raw,
#     175         log=log,
#     176         num_categories=num_categories,
#     177         categories_order=categories_order,
#     178         title=title,
#     179         figsize=figsize,
#     180         gene_symbols=gene_symbols,
#     181         var_group_positions=var_group_positions,
#     182         var_group_labels=var_group_labels,
#     183         var_group_rotation=var_group_rotation,
#     184         layer=layer,
#     185         ax=ax,
#     186         vmin=vmin,
#     187         vmax=vmax,
#     188         vcenter=vcenter,
#     189         norm=norm,
#     190         **kwds,
#     191     )
#     193     # Set default style parameters
#     194     self.cmap = self.DEFAULT_COLORMAP
#
#     [... skipping hidden 1 frame]
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\scanpy\plotting\_baseplot_class.py:147, in BasePlot.__init__(***failed resolving arguments***)
#     144 self.var_group_rotation = var_group_rotation
#     145 self.width, self.height = figsize if figsize is not None else (None, None)
# --> 147 self.categories, self.obs_tidy = _prepare_dataframe(
#     148     adata,
#     149     self.var_names,
#     150     groupby,
#     151     use_raw=use_raw,
#     152     log=log,
#     153     num_categories=num_categories,
#     154     layer=layer,
#     155     gene_symbols=gene_symbols,
#     156 )
#     157 if len(self.categories) > self.MAX_NUM_CATEGORIES:
#     158     msg = (
#     159         f"Over {self.MAX_NUM_CATEGORIES} categories found. "
#     160         "Plot would be very large."
#     161     )
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\scanpy\plotting\_anndata.py:2075, in _prepare_dataframe(adata, var_names, groupby, use_raw, log, num_categories, layer, gene_symbols)
#    2073     groupby.remove(groupby_index)
#    2074 keys = list(groupby) + list(np.unique(var_names))
# -> 2075 obs_tidy = get.obs_df(
#    2076     adata, keys=keys, layer=layer, use_raw=use_raw, gene_symbols=gene_symbols
#    2077 )
#    2078 assert np.all(np.array(keys) == np.array(obs_tidy.columns))
#    2080 if groupby_index is not None:
#    2081     # reset index to treat all columns the same way.
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\scanpy\get\get.py:287, in obs_df(adata, keys, obsm_keys, layer, gene_symbols, use_raw)
#     284     var = adata.var
#     285 alias_index = pd.Index(var[gene_symbols]) if gene_symbols is not None else None
# --> 287 obs_cols, var_idx_keys, var_symbols = _check_indices(
#     288     adata.obs,
#     289     var.index,
#     290     dim="obs",
#     291     keys=keys,
#     292     alias_index=alias_index,
#     293     use_raw=use_raw,
#     294 )
#     296 # Make df
#     297 df = pd.DataFrame(index=adata.obs_names)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\scanpy\get\get.py:187, in _check_indices(dim_df, alt_index, dim, keys, alias_index, use_raw)
#     182 if len(not_found) > 0:
#     183     msg = (
#     184         f"Could not find keys {not_found!r} in columns of `adata.{dim}` or in"
#     185         f" {alt_repr}.{alt_search_repr}."
#     186     )
# --> 187     raise KeyError(msg)
#     189 return col_keys, index_keys, index_aliases
#
# KeyError: "Could not find keys [np.str_('CD8A'), np.str_('CD8B')] in columns of `adata.obs` or in adata.var_names."

# %%
sc.get.rank_genes_groups_df(
    adata_qc,
    group="7"
).head(20)
# Out:
#             names    scores  logfoldchanges         pvals     pvals_adj
# 0   RP11-511B23.1  8.625586             NaN  6.376546e-18  2.125515e-16
# 1          NCKAP1  8.617364             NaN  6.851300e-18  2.141031e-16
# 2            PAK3  8.607897             NaN  7.441320e-18  2.259850e-16
# 3           USP30  8.607648             NaN  7.457506e-18  2.259850e-16
# 4           OBSCN  8.558318        1.388889  1.145261e-17  2.899394e-16
# 5   CTA-250D10.23  8.550844             NaN  1.221919e-17  2.966400e-16
# 6          DRAXIN  8.497528             NaN  1.936708e-17  4.077281e-16
# 7   RP11-164H13.1  8.485071             NaN  2.155871e-17  4.445094e-16
# 8           KCNG1  8.477098             NaN  2.308794e-17  4.617588e-16
# 9           PDZD4  8.455672        0.668021  2.774834e-17  5.138581e-16
# 10  RP11-324I22.4  8.449693             NaN  2.920694e-17  5.359071e-16
# 11           GNG3  8.418550       -2.388816  3.811701e-17  6.629046e-16
# 12   CTB-152G17.6  8.407090             NaN  4.203075e-17  7.184743e-16
# 13         OSBPL7  8.404848        2.605267  4.284159e-17  7.261287e-16
# 14            IL6  8.403603       -0.355785  4.329871e-17  7.277094e-16
# 15          BACE2  8.356515             NaN  6.459824e-17  1.033572e-15
# 16         PGM2L1  8.355518        2.749387  6.514597e-17  1.034063e-15
# 17          EXOC6  8.314410             NaN  9.220955e-17  1.397114e-15
# 18         ZNF175  8.287005        0.405466  1.161357e-16  1.729468e-15
# 19   RP11-428G5.5  8.284016             NaN  1.190902e-16  1.738544e-15

# %%
sc.pl.umap(
    adata_qc,
    color=["PPBP","PF4","FCER1A","FCGR3A"]
)

# %%
adata_qc.write(results_file)
